# %%
import xarray as xr
import rioxarray
import pandas as pd
import numpy as np

# %%
cd /home/jovyan
# Out:
# /home/jovyan

# %%
bathy=rioxarray.open_rasterio('ohw23-proj-habitatmapping/data/BA_Galway10m.tif')
backs=rioxarray.open_rasterio('ohw23-proj-habitatmapping/data/BS_Galway10m.tif')

# %%
#rds = rioxarray.open_rasterio(
#    'ohw23-proj-habitatmapping/data/backscatter/IE_GSI_MI_Backscatter_40m_Offshore_IE_WGS84_LAT_TIFF.tif')

# %%
#rds

# %%
#rdssmall= rds.sel(y=slice(53,52.5)).sel(x=slice(-16,-15.5))

# %%
#rdssmall

# %%
bathy.sel(band=1).plot()

# %%
backs.sel(band=1).plot()
