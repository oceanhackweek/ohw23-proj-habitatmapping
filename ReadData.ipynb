# %%
import xarray as xr
import rioxarray
import pandas as pd
import numpy as np

# %%
cd /home/jovyan
# Out:
# /home/jovyan

# %%
rds = rioxarray.open_rasterio(
    'ohw23-proj-habitatmapping/data/backscatter/IE_GSI_MI_Backscatter_40m_Offshore_IE_WGS84_LAT_TIFF.tif')

# %%
rds
# Out:
# <xarray.DataArray (band: 3, y: 25881, x: 45776)>
# [3554185968 values with dtype=uint8]
# Coordinates:
#   * band         (band) int64 1 2 3
#   * x            (x) float64 -25.42 -25.42 -25.42 -25.42 ... -4.751 -4.751 -4.75
#   * y            (y) float64 58.36 58.36 58.36 58.36 ... 46.68 46.68 46.68 46.67
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:           Area
#     DataType:                Generic
#     RepresentationType:      ATHEMATIC
#     STATISTICS_COVARIANCES:  447.7288559903119,447.728855990428,447.728855990428
#     STATISTICS_MAXIMUM:      254
#     STATISTICS_MEAN:         116.93263096869
#     STATISTICS_MEDIAN:       120.0
#     STATISTICS_MINIMUM:      1
#     STATISTICS_SKIPFACTORX:  1
#     STATISTICS_SKIPFACTORY:  1
#     STATISTICS_STDDEV:       21.159604343898
#     _FillValue:              0
#     scale_factor:            1.0
#     add_offset:              0.0
#     units:                   ('metre', 'metre', 'metre')

# %%
rdssmall= rds.sel(y=slice(53,52.5)).sel(x=slice(-16,-15.5))

# %%
rdssmall
# Out:
# <xarray.DataArray (band: 3, y: 1107, x: 1108)>
# [3679668 values with dtype=uint8]
# Coordinates:
#   * band         (band) int64 1 2 3
#   * x            (x) float64 -16.0 -16.0 -16.0 -16.0 ... -15.5 -15.5 -15.5 -15.5
#   * y            (y) float64 53.0 53.0 53.0 53.0 53.0 ... 52.5 52.5 52.5 52.5
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:           Area
#     DataType:                Generic
#     RepresentationType:      ATHEMATIC
#     STATISTICS_COVARIANCES:  447.7288559903119,447.728855990428,447.728855990428
#     STATISTICS_MAXIMUM:      254
#     STATISTICS_MEAN:         116.93263096869
#     STATISTICS_MEDIAN:       120.0
#     STATISTICS_MINIMUM:      1
#     STATISTICS_SKIPFACTORX:  1
#     STATISTICS_SKIPFACTORY:  1
#     STATISTICS_STDDEV:       21.159604343898
#     _FillValue:              0
#     scale_factor:            1.0
#     add_offset:              0.0
#     units:                   ('metre', 'metre', 'metre')

# %%
rdssmall.sel(band=1).plot()
