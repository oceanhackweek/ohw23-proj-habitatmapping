# %%
import xarray as xr
import pandas as pd
import numpy as np

# %% [markdown]
# ## open clipped netcdf4 file for example file (allegedly backscatter data)

# %%
ds = xr.open_dataset('data/sth.nc')

# %%
ds.Band1.plot.imshow()

# %%
ds.Band2.plot.imshow()

# %%
ds.Band3.plot.imshow()
